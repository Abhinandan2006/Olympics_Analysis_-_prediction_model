# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('../data/athlete_events.csv')
region_df = pd.read_csv('../data/noc_regions.csv')

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
df.shape
# Out:
# (271116, 15)

# %%
#we need only the data for summer olympics
df = df[df['Season'] == 'Winter']

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %%
#we can find out region form noc
df = df.merge(region_df, on='NOC', how = 'left')

# %%
pd.get_dummies(df['Medal']).astype(int)
# Out:
#        Bronze  Gold  Silver
# 0           0     0       0
# 1           0     0       0
# 2           0     0       0
# 3           0     0       0
# 4           0     0       0
# ...       ...   ...     ...
# 48559       0     0       0
# 48560       0     0       0
# 48561       0     0       0
# 48562       0     0       0
# 48563       0     0       0
#
# [48564 rows x 3 columns]

# %%
df = pd.concat([df, pd.get_dummies(df['Medal']).astype(int)], axis=1)

# %%
df
# Out:
#            ID                      Name Sex   Age  Height  Weight  \
# 0           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 1           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 2           5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 3           5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 4           5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...       ...                       ...  ..   ...     ...     ...
# 48559  135569                Andrzej ya   M  29.0   179.0    89.0
# 48560  135570                  Piotr ya   M  27.0   176.0    59.0
# 48561  135570                  Piotr ya   M  27.0   176.0    59.0
# 48562  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 48563  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#               Team  NOC        Games  Year  Season            City  \
# 0      Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
temp_df = df.dropna(subset=['Medal'])

# %%
temp_df.drop_duplicates(subset=['Team', 'NOC', 'Games', 'Year', 'City', 'Sport', 'Event', 'Medal'], inplace=True)
# Out:
# C:\Users\Ayushi\AppData\Local\Temp\ipykernel_18240\1975138824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df.drop_duplicates(subset=['Team', 'NOC', 'Games', 'Year', 'City', 'Sport', 'Event', 'Medal'], inplace=True)

# %%
new_df = temp_df[temp_df['region'] == 'Australia']
new_df = new_df.groupby('Year').count()['Medal'].reset_index()

# %%
new_df
# Out:
#    Year  Medal
# 0  1924      1
# 1  1994      1
# 2  1998      1
# 3  2002      2
# 4  2006      2
# 5  2010      3
# 6  2014      3

# %%
fig = px.line(
    new_df,
    x="Year",
    y="Medal",
    markers=True,
    title = None
)

fig.update_traces(line_shape='spline', line=dict(width=3, color='royalblue'))

fig.update_layout(
    plot_bgcolor="white",
    xaxis_title="Olympic Edition (Year)",
    yaxis_title="Number of Participating Countries",
    title_font=dict(size=12, family="Arial", color="black"),
    xaxis=dict(showgrid=True, gridcolor="darkgray"),
    yaxis=dict(showgrid=True, gridcolor="darkgray")
)

fig.show()

# %%
new_df1 = temp_df[temp_df['region'] == 'Albania']
pt = new_df1.pivot_table(index='Sport', columns='Year', values='Medal', aggfunc='count')
plt.figure(figsize=(20,20))
if pt.empty:
    print("data not found")
else:
    sns.heatmap(pt.fillna(0), annot=True)
# Out:
# data not found
